# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054.0
# Trainable params: 528,054.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 0.87181, saving model to model.weights.best.hdf5
# 108s - loss: 0.9268 - acc: 0.6839 - val_loss: 0.8718 - val_acc: 0.7110
# Epoch 2/100
# Epoch 00001: val_loss improved from 0.87181 to 0.81873, saving model to model.weights.best.hdf5
# 110s - loss: 0.8737 - acc: 0.6988 - val_loss: 0.8187 - val_acc: 0.7274
# Epoch 3/100
# Epoch 00002: val_loss did not improve
# 116s - loss: 0.8343 - acc: 0.7111 - val_loss: 0.8459 - val_acc: 0.7166
# Epoch 4/100
# Epoch 00003: val_loss improved from 0.81873 to 0.79510, saving model to model.weights.best.hdf5
# 114s - loss: 0.8031 - acc: 0.7199 - val_loss: 0.7951 - val_acc: 0.7354
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 109s - loss: 0.7776 - acc: 0.7268 - val_loss: 0.8035 - val_acc: 0.7292
# Epoch 6/100
# Epoch 00005: val_loss did not improve
# 104s - loss: 0.7521 - acc: 0.7367 - val_loss: 0.8000 - val_acc: 0.7236
# Epoch 7/100
# Epoch 00006: val_loss improved from 0.79510 to 0.76576, saving model to model.weights.best.hdf5
# 108s - loss: 0.7262 - acc: 0.7470 - val_loss: 0.7658 - val_acc: 0.7486
# Epoch 8/100
# Epoch 00007: val_loss improved from 0.76576 to 0.76389, saving model to model.weights.best.hdf5
# 101s - loss: 0.7101 - acc: 0.7512 - val_loss: 0.7639 - val_acc: 0.7414
# Epoch 9/100
# Epoch 00008: val_loss improved from 0.76389 to 0.74361, saving model to model.weights.best.hdf5
# 102s - loss: 0.6865 - acc: 0.7601 - val_loss: 0.7436 - val_acc: 0.7506
# Epoch 10/100
# Epoch 00009: val_loss improved from 0.74361 to 0.74080, saving model to model.weights.best.hdf5
# 103s - loss: 0.6667 - acc: 0.7622 - val_loss: 0.7408 - val_acc: 0.7498
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 102s - loss: 0.6531 - acc: 0.7715 - val_loss: 0.7767 - val_acc: 0.7388
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 97s - loss: 0.6294 - acc: 0.7770 - val_loss: 0.7452 - val_acc: 0.7486
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 96s - loss: 0.6156 - acc: 0.7818 - val_loss: 0.7440 - val_acc: 0.7548
# Epoch 14/100
# Epoch 00013: val_loss improved from 0.74080 to 0.74065, saving model to model.weights.best.hdf5
# 97s - loss: 0.6017 - acc: 0.7871 - val_loss: 0.7406 - val_acc: 0.7544
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 99s - loss: 0.5908 - acc: 0.7916 - val_loss: 0.7570 - val_acc: 0.7480
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 98s - loss: 0.5726 - acc: 0.7953 - val_loss: 0.7478 - val_acc: 0.7440
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 98s - loss: 0.5635 - acc: 0.8001 - val_loss: 0.7441 - val_acc: 0.7612
# Epoch 18/100
# Epoch 00017: val_loss improved from 0.74065 to 0.73403, saving model to model.weights.best.hdf5
# 96s - loss: 0.5520 - acc: 0.8015 - val_loss: 0.7340 - val_acc: 0.7542
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 96s - loss: 0.5427 - acc: 0.8090 - val_loss: 0.7438 - val_acc: 0.7560
# Epoch 20/100
# Epoch 00019: val_loss improved from 0.73403 to 0.72969, saving model to model.weights.best.hdf5
# 98s - loss: 0.5298 - acc: 0.8111 - val_loss: 0.7297 - val_acc: 0.7596
# Epoch 21/100
# Epoch 00020: val_loss improved from 0.72969 to 0.72679, saving model to model.weights.best.hdf5
# 97s - loss: 0.5200 - acc: 0.8141 - val_loss: 0.7268 - val_acc: 0.7618
# Epoch 22/100
# Epoch 00021: val_loss improved from 0.72679 to 0.71529, saving model to model.weights.best.hdf5
# 92s - loss: 0.5103 - acc: 0.8190 - val_loss: 0.7153 - val_acc: 0.7642
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 48s - loss: 0.5103 - acc: 0.8203 - val_loss: 0.7426 - val_acc: 0.7518
# Epoch 24/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-5bacde4ad941> in <module>()
#       6 hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
#       7           validation_data=(x_valid, y_valid), callbacks=[checkpointer],
# ----> 8           verbose=2, shuffle=True)
#
# C:\Users\A138262\AppData\Local\Continuum\Anaconda3\envs\aind-dl\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     843                               class_weight=class_weight,
#     844                               sample_weight=sample_weight,
# --> 845                               initial_epoch=initial_epoch)
#     846
#     847     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# C:\Users\A138262\AppData\Local\Continuum\Anaconda3\envs\aind-dl\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1483                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1484                               callback_metrics=callback_metrics,
# -> 1485                               initial_epoch=initial_epoch)
#    1486
#    1487     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# C:\Users\A138262\AppData\Local\Continuum\Anaconda3\envs\aind-dl\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1138                 batch_logs['size'] = len(batch_ids)
#    1139                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1140                 outs = f(ins_batch)
#    1141                 if not isinstance(outs, list):
#    1142                     outs = [outs]
#
# C:\Users\A138262\AppData\Local\Continuum\Anaconda3\envs\aind-dl\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2071         session = get_session()
#    2072         updated = session.run(self.outputs + [self.updates_op],
# -> 2073                               feed_dict=feed_dict)
#    2074         return updated[:len(self.outputs)]
#    2075
#
# C:\Users\A138262\AppData\Local\Continuum\Anaconda3\envs\aind-dl\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Users\A138262\AppData\Local\Continuum\Anaconda3\envs\aind-dl\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# C:\Users\A138262\AppData\Local\Continuum\Anaconda3\envs\aind-dl\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Users\A138262\AppData\Local\Continuum\Anaconda3\envs\aind-dl\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# C:\Users\A138262\AppData\Local\Continuum\Anaconda3\envs\aind-dl\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7454

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
